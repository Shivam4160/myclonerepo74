# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

# %%
auto = pd.read_csv("auto.csv")

auto = auto.sort_values(by="horsepower")

x = auto[["horsepower"]].values
y = auto["mpg"].values

poly = PolynomialFeatures(degree=2, include_bias=False)
x_poly = poly.fit_transform(x)

polymodel = LinearRegression()
polymodel.fit(x_poly, y)

print("Intercept:", polymodel.intercept_)
print("Coefficients:", polymodel.coef_)

y_poly_pred = polymodel.predict(x_poly)

plt.scatter(x, y)
plt.plot(x, y_poly_pred, color="red")
plt.xlabel("Horsepower")
plt.ylabel("MPG")
plt.show()
# Out:
# Intercept: 56.90009970211301
# Coefficients: [-0.46618963  0.00123054]
